# %% [markdown]
# <a href="https://colab.research.google.com/github/alcalcides/PythonLab/blob/master/PythonLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variáveis e saída padrão

# %%
print("Hello, Python!")

year = 2026;
print(year)
print("It's ", year)

name = "Bob"
print(name)
print('How are you,', name, '\b?') #It is a inline comment
print("Hi,", end= " ") # It won't break line
print("I'm great!")
print("Everybody knows that 1 + 2 is ", 1+2)
# Out:
# Hello, Python!
# 2026
# It's  2026
# Bob
# ?
# Hi, I'm great!
# Everybody knows that 1 + 2 is  3

# %% [markdown]
# Environment check

# %%
import sys

print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %% [markdown]
# Data types

# %%
x = 1
print(type(x))
x = "California"
type(x)
# Out:
# <class 'int'>
# int

# %%
type("hi")
# Out:
# str

# %%
type(int("100"))
# Out:
# int

# %%
type(str(100))
# Out:
# str

# %%
str(3)+"0"
# Out:
# '30'

# %%
int("1") + int(3)
# Out:
# 3

# %%
print(type(float(1) + 0.5))
print(type(1+0.5))
print(type(1+2))
print(type(str(10)))
# Out:
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'str'>

# %%
#snake_case
first_second_third = "me", "you", "he_she_it" #underscore is the only allowed special character
#camelCase
firstSecondAndThird = "meYouHeSheIt"
#PascalCase
FirstSecondAndThird = "MeYouHeSheIt"

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
x = y = z = "Apple"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry
# Apple
# Apple
# Apple

# %%
# extract from list
level1, level2, level3, level4  = [1, 2, 3, 4] #in JS it would be [level1, level2....]
print(level1)
print(level2)
print(level3)
print(level4)
# Out:
# 1
# 2
# 3
# 4

# %%
x = "Python"
y = "is"
z = "very similar to JS"
print(x + y + z) #concatenate
print(x,y,z) #add space
# Out:
# Pythonisvery similar to JS
# Python is very similar to JS
